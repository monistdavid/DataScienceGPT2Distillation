# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import os
os.chdir("/content/drive/My Drive/Northeastern/data research project")

# %%
# !pip install -r requirements.txt

# %%
# !python distillation/scripts/binarized_data.py \
    --file_path data/wiki.valid.tokens \
    --tokenizer_type gpt2 \
    --tokenizer_name gpt2 \
    --dump_file data/binarized_text_valid
# Out:
# 04/17/2023 12:05:37 - INFO - __main__ - Loading Tokenizer (gpt2)
# 04/17/2023 12:05:37 - INFO - __main__ - Loading text from data/wiki.valid.tokens
# 04/17/2023 12:05:38 - INFO - __main__ - Start encoding
# 04/17/2023 12:05:38 - INFO - __main__ - 3760 examples to process.
# 04/17/2023 12:05:40 - INFO - __main__ - Finished binarization
# 04/17/2023 12:05:40 - INFO - __main__ - 3760 examples processed.
# 04/17/2023 12:05:40 - INFO - __main__ - Dump to data/binarized_text_valid.gpt2.pickle

# %%
# !python distillation/scripts/token_counts.py \
    --data_file data/binarized_text_valid.gpt2.pickle \
    --token_counts_dump data/token_counts.binarized_text_valid.gpt2.pickle \
    --vocab_size 50257
# Out:
# 04/17/2023 12:24:18 - INFO - __main__ - Loading data from data/binarized_text_valid.gpt2.pickle
# 04/17/2023 12:24:18 - INFO - __main__ - Counting occurrences for MLM.
# 04/17/2023 12:24:18 - INFO - __main__ - Dump to data/token_counts.binarized_text_valid.gpt2.pickle

# %%
# !python distillation/train.py --student_type gpt2 --student_config distillation/training_configs/distilgpt2.json --teacher_type gpt2 --teacher_name gpt2 --alpha_ce 5.0 --alpha_mlm 0.0 --alpha_cos 1.0 --alpha_clm 2.0 --freeze_pos_embs --dump_path serialization_dir/my_first_training --data_file data/binarized_text_train.gpt2.pickle --token_counts data/token_counts.binarized_text_train.gpt2.pickle --force # overwrites the `dump_path` if it already exists.
